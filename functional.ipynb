# %% [markdown]
# ## Project: Let's Go Functional

# %% [markdown]
# ## 🗂 Sample Data:
#
# ```python
#
# stocks_info = [
#     {
#         "代號": "1101",
#         "名稱": "台泥",
#         "國際證券辨識號碼(ISIN Code)": "TW0001101004",
#         "市場別": "上市",
#         "產業別": "水泥工業"
#     },
#     {
#         "代號": "2609",
#         "名稱": "陽明",
#         "國際證券辨識號碼(ISIN Code)": "TW0002609005",
#         "市場別": "上市",
#         "產業別": "航運業"
#     },
#     {
#         "代號": "2836",
#         "名稱": "高雄銀",
#         "國際證券辨識號碼(ISIN Code)": "TW0002836004",
#         "市場別": "上市",
#         "產業別": "金融保險業"
#     },
#     {
#         "代號": "2850",
#         "名稱": "新產",
#         "國際證券辨識號碼(ISIN Code)": "TW0002850005",
#         "市場別": "上市",
#         "產業別": "金融保險業"
#     },
#     {
#         "代號": "3711",
#         "名稱": "日月光投控",
#         "國際證券辨識號碼(ISIN Code)": "TW0003711008",
#         "市場別": "上市",
#         "產業別": "半導體業"
#     },
#     {
#         "代號": "8473",
#         "名稱": "山林水",
#         "國際證券辨識號碼(ISIN Code)": "TW0008473000",
#         "市場別": "上市",
#         "產業別": "綠能環保"
#     }
# ]
#
# stocks_with_last_5year_avg_roe = [
#     {
#         "代號": "2609",
#         "平均 ROE (%)": "39.2",
#         "平均 財報 評分": "76"
#     },
#     {
#         "代號": "2850",
#         "平均 ROE (%)": "16.4",
#         "平均 財報 評分": "65"
#     },
#     {
#         "代號": "3711",
#         "平均 ROE (%)": "14.9",
#         "平均 財報 評分": "49"
#     },
#     {
#         "代號": "1101",
#         "平均 ROE (%)": "5.25",
#         "平均 財報 評分": "50"
#     },
#     {
#         "代號": "2836",
#         "平均 ROE (%)": "4.87",
#         "平均 財報 評分": "54"
#     },
#     {
#         "代號": "3540",
#         "平均 ROE (%)": "2.59",
#         "平均 財報 評分": "36"
#     },
#     {
#         "代號": "8473",
#         "平均 ROE (%)": "2.47",
#         "平均 財報 評分": "38"
#     }
# ]
#
# stocks_with_pbr = [
#     {
#         "代號": "2609",
#         "成交": "52.3",
#         "PBR": "0.57"
#     },
#     {
#         "代號": "1101",
#         "成交": "21.2",
#         "PBR": "0.73"
#     },
#     {
#         "代號": "2836",
#         "成交": "12.1",
#         "PBR": "0.86"
#     },
#     {
#         "代號": "8473",
#         "成交": "35.7",
#         "PBR": "0.96"
#     },
#     {
#         "代號": "3540",
#         "成交": "29.3",
#         "PBR": "1.24"
#     },
#     {
#         "代號": "2850",
#         "成交": "118",
#         "PBR": "1.9"
#     },
#     {
#         "代號": "3711",
#         "成交": "210.5",
#         "PBR": "2.9"
#     }
# ]
#
# stocks_with_per = [
#     {
#         "代號": "2609",
#         "市 場": "市",
#         "PER": "6.68"
#     },
#     {
#         "代號": "2850",
#         "市 場": "市",
#         "PER": "10.7"
#     },
#     {
#         "代號": "8473",
#         "市 場": "市",
#         "PER": "17.2"
#     },
#     {
#         "代號": "2836",
#         "市 場": "市",
#         "PER": "18.9"
#     },
#     {
#         "代號": "3711",
#         "市 場": "市",
#         "PER": "25.9"
#     }
# ]
# ```

# %%
# Data definitions in Python:
stocks_info = [
    {
        "代號": "1101",
        "名稱": "台泥",
        "國際證券辨識號碼(ISIN Code)": "TW0001101004",
        "市場別": "上市",
        "產業別": "水泥工業"
    },
    {
        "代號": "2609",
        "名稱": "陽明",
        "國際證券辨識號碼(ISIN Code)": "TW0002609005",
        "市場別": "上市",
        "產業別": "航運業"
    },
    {
        "代號": "2836",
        "名稱": "高雄銀",
        "國際證券辨識號碼(ISIN Code)": "TW0002836004",
        "市場別": "上市",
        "產業別": "金融保險業"
    },
    {
        "代號": "2850",
        "名稱": "新產",
        "國際證券辨識號碼(ISIN Code)": "TW0002850005",
        "市場別": "上市",
        "產業別": "金融保險業"
    },
    {
        "代號": "3711",
        "名稱": "日月光投控",
        "國際證券辨識號碼(ISIN Code)": "TW0003711008",
        "市場別": "上市",
        "產業別": "半導體業"
    },
    {
        "代號": "8473",
        "名稱": "山林水",
        "國際證券辨識號碼(ISIN Code)": "TW0008473000",
        "市場別": "上市",
        "產業別": "綠能環保"
    }
]

stocks_with_last_5year_avg_roe = [
    {
        "代號": "2609",
        "平均 ROE (%)": "39.2",
        "平均 財報 評分": "76"
    },
    {
        "代號": "2850",
        "平均 ROE (%)": "16.4",
        "平均 財報 評分": "65"
    },
    {
        "代號": "3711",
        "平均 ROE (%)": "14.9",
        "平均 財報 評分": "49"
    },
    {
        "代號": "1101",
        "平均 ROE (%)": "5.25",
        "平均 財報 評分": "50"
    },
    {
        "代號": "2836",
        "平均 ROE (%)": "4.87",
        "平均 財報 評分": "54"
    },
    {
        "代號": "3540",
        "平均 ROE (%)": "2.59",
        "平均 財報 評分": "36"
    },
    {
        "代號": "8473",
        "平均 ROE (%)": "2.47",
        "平均 財報 評分": "38"
    }
]

stocks_with_pbr = [
    {
        "代號": "2609",
        "成交": "52.3",
        "PBR": "0.57"
    },
    {
        "代號": "1101",
        "成交": "21.2",
        "PBR": "0.73"
    },
    {
        "代號": "2836",
        "成交": "12.1",
        "PBR": "0.86"
    },
    {
        "代號": "8473",
        "成交": "35.7",
        "PBR": "0.96"
    },
    {
        "代號": "3540",
        "成交": "29.3",
        "PBR": "1.24"
    },
    {
        "代號": "2850",
        "成交": "118",
        "PBR": "1.9"
    },
    {
        "代號": "3711",
        "成交": "210.5",
        "PBR": "2.9"
    }
]

stocks_with_per = [
    {
        "代號": "2609",
        "市 場": "市",
        "PER": "6.68"
    },
    {
        "代號": "2850",
        "市 場": "市",
        "PER": "10.7"
    },
    {
        "代號": "8473",
        "市 場": "市",
        "PER": "17.2"
    },
    {
        "代號": "2836",
        "市 場": "市",
        "PER": "18.9"
    },
    {
        "代號": "3711",
        "市 場": "市",
        "PER": "25.9"
    }
]

# %%
len(stocks_info)
# Out:
# 6

# %%
len(stocks_with_last_5year_avg_roe)
# Out:
# 7

# %%
len(stocks_with_per)
# Out:
# 5

# %%
len(stocks_with_pbr)
# Out:
# 7
